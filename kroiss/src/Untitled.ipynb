# %%
import talos as ta
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
r = ta.Reporting('E:\\tkroiss\\99_Basetraining_HypOpt_CMSE\\CMSE_Talos_Results.csv')

# %%
r.data
# Out:
#      round_epochs      val_loss  val_circular_mae          loss  circular_mae  \
# 0               1    781.044434         12.933194  1.191946e+03     18.219785
# 1               1   1193.104858         18.596724  1.678890e+03     25.108517
# 2               1   1248.362793         18.388109  1.858865e+03     24.669826
# 3               1   1388.374146         20.852116  1.941823e+03     28.116759
# 4               1    748.996887         12.975194  1.183530e+03     18.857616
# 5               1   2247.885010         38.336666  3.205323e+03     43.716556
# 6               1   1614.253296         23.964285  5.041979e+03     39.515800
# 7               1   1296.694214         20.964525  2.026486e+03     29.226897
# 8               1    662.138306         12.145955  1.375738e+03     20.269243
# 9               1   1420.724976         23.557558  2.270769e+03     29.334495
# 10              1   2140.826172         27.901897  7.105530e+04     78.436350
# ...

# %%
r.high('val_circular_mae')
# Out:
# 1334058.625

# %%
r.plot_line('val_loss')

# %%
r.plot_corr('val_circular_mae')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d41722c787ce> in <module>
# ----> 1 r.plot_corr('val_circular_mae')
#
# TypeError: plot_corr() missing 1 required positional argument: 'exclude'

# %%
r.best_params('val_circular_mae', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a7c8cbe15aa6> in <module>
# ----> 1 r.best_params('val_circular_mae', ascending=True)
#
# TypeError: best_params() missing 1 required positional argument: 'exclude'

# %%
r.rounds2high('val_circular_mae')
# Out:
# 38
